# %% [markdown]
# # 01. Import libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Import data

# %%
# Import customers.csv as df_customers
df_customers = pd.read_csv(r'C:\Users\David\Desktop\Instacart Basket Analysis\02 Data\Original Data\customers.csv', index_col = False)

# %%
path =  r'C:\Users\David\Desktop\Instacart Basket Analysis'

# %%
# Check data
df_customers.head()
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
df_customers.shape
# Out:
# (206209, 10)

# %%
df_customers.describe()
# Out:
#              user_id            Age   n_dependants         income
# count  206209.000000  206209.000000  206209.000000  206209.000000
# mean   103105.000000      49.501646       1.499823   94632.852548
# std     59527.555167      18.480962       1.118433   42473.786988
# min         1.000000      18.000000       0.000000   25903.000000
# 25%     51553.000000      33.000000       0.000000   59874.000000
# 50%    103105.000000      49.000000       1.000000   93547.000000
# 75%    154657.000000      66.000000       3.000000  124244.000000
# max    206209.000000      81.000000       3.000000  593901.000000

# %% [markdown]
# # Data Wrangling

# %%
# Changing variable 'user_id' to string
df_customers['user_id'] = df_customers['user_id'].astype('str')

# %%
df_customers['user_id'].dtype
# Out:
# dtype('O')

# %%
df_customers.dtypes
# Out:
# user_id         object
# First Name      object
# Surnam          object
# Gender          object
# STATE           object
# Age              int64
# date_joined     object
# n_dependants     int64
# fam_status      object
# income           int64
# dtype: object

# %%
# Identifying most frequent age 
df_customers['Age'].value_counts(dropna = False)
# Out:
# 19    3329
# 55    3317
# 51    3317
# 56    3306
# 32    3305
#       ...
# 65    3145
# 25    3127
# 66    3114
# 50    3102
# 36    3101
# Name: Age, Length: 64, dtype: int64

# %%
# Renaming 'n_dependants' column 
df_customers.rename(columns = {'n_dependants' : 'dependents'}, inplace = True)

# %%
df_customers.head()
# Out:
#   user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0   26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1   33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2   65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3  125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4  130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    dependents fam_status  income
# 0           3    married  165665
# 1           0     single   59285
# 2           2    married   99568
# 3           0     single   42049
# 4           1    married   40374

# %% [markdown]
# # Data consistency

# %%
# Checking for missing values
df_customers.isnull().sum()
# Out:
# user_id            0
# First Name     11259
# Surnam             0
# Gender             0
# STATE              0
# Age                0
# date_joined        0
# dependents         0
# fam_status         0
# income             0
# dtype: int64

# %%
df_nan = df_customers[df_customers['First Name'].isnull() == True]

# %%
df_nan
# Out:
#        user_id First Name    Surnam  Gender         STATE  Age date_joined  \
# 53       76659        NaN   Gilbert    Male      Colorado   26    1/1/2017
# 73       13738        NaN     Frost  Female     Louisiana   39    1/1/2017
# 82       89996        NaN    Dawson  Female        Oregon   52    1/1/2017
# 99       96166        NaN   Oconnor    Male      Oklahoma   51    1/1/2017
# 105      29778        NaN    Dawson  Female          Utah   63    1/1/2017
# ...        ...        ...       ...     ...           ...  ...         ...
# 206038  121317        NaN    Melton    Male  Pennsylvania   28   3/31/2020
# 206044  200799        NaN  Copeland  Female        Hawaii   52    4/1/2020
# 206090  167394        NaN     Frost  Female        Hawaii   61    4/1/2020
# 206162  187532        NaN     Floyd  Female    California   39    4/1/2020
# 206171  116898        NaN   Delgado  Female      Colorado   23    4/1/2020
#
#         dependents fam_status  income
# ...

# %%
# Checking for duplicates
df_dups = df_customers[df_customers.duplicated()]

# %%
df_dups
# Out:
# Empty DataFrame
# Columns: [user_id, First Name, Surnam, Gender, STATE, Age, date_joined, dependents, fam_status, income]
# Index: []

# %%
df_customers.shape
# Out:
# (206209, 10)

# %%
df_customers.head()
# Out:
#   user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0   26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1   33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2   65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3  125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4  130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    dependents fam_status  income
# 0           3    married  165665
# 1           0     single   59285
# 2           2    married   99568
# 3           0     single   42049
# 4           1    married   40374

# %%
# Export clean data
df_customers.to_csv(os.path.join(path, '02 Data','Prepared Data', 'customers_checked.csv'))

# %% [markdown]
# # Combine data

# %%
# Import customers_checked data
df_cus_checked = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'customers_checked.csv'), index_col = False)

# %%
# Import ords_prods_merged
ords_prods = pd.read_pickle(r'C:\Users\David\Desktop\Instacart Basket Analysis\02 Data\Prepared Data\orders_products_merged_updated_V3.pkl')

# %%
# Check output
ords_prods.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  order_hour  \
# 0   2539329        1    prior             1                   2           8
# 1   2398795        1    prior             2                   3           7
# 2    473747        1    prior             3                   3          12
# 3   2254736        1    prior             4                   4           7
# 4    431534        1    prior             5                   4          15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  ...  \
# 0                     7.0         196                  1          0  ...
# 1                    15.0         196                  1          1  ...
# 2                    21.0         196                  1          1  ...
# 3                    29.0         196                  1          1  ...
# 4                    28.0         196                  1          1  ...
#
# ...

# %%
df_cus_checked.head()
# Out:
#    Unnamed: 0  user_id First Name    Surnam  Gender       STATE  Age  \
# 0           0    26711    Deborah  Esquivel  Female    Missouri   48
# 1           1    33890   Patricia      Hart  Female  New Mexico   36
# 2           2    65803    Kenneth    Farley    Male       Idaho   35
# 3           3   125935   Michelle     Hicks  Female        Iowa   40
# 4           4   130797        Ann   Gilmore  Female    Maryland   26
#
#   date_joined  dependents fam_status  income
# 0    1/1/2017           3    married  165665
# 1    1/1/2017           0     single   59285
# 2    1/1/2017           2    married   99568
# 3    1/1/2017           0     single   42049
# 4    1/1/2017           1    married   40374

# %%
# Combine data
df_merged = ords_prods.merge(df_cus_checked, on = 'user_id')

# %%
# Check output
df_merged.shape
# Out:
# (32404859, 36)

# %%
df_merged.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  order_hour  \
# 0   2539329        1    prior             1                   2           8
# 1   2398795        1    prior             2                   3           7
# 2    473747        1    prior             3                   3          12
# 3   2254736        1    prior             4                   4           7
# 4    431534        1    prior             5                   4          15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  ...  \
# 0                     7.0         196                  1          0  ...
# 1                    15.0         196                  1          1  ...
# 2                    21.0         196                  1          1  ...
# 3                    29.0         196                  1          1  ...
# 4                    28.0         196                  1          1  ...
#
# ...

# %%
df_merged['_merge'].value_counts()
# Out:
# both          32404859
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
df_merged.columns
# Out:
# Index(['order_id', 'user_id', 'eval_set', 'order_number', 'orders_day_of_week',
#        'order_hour', 'days_since_prior_order', 'product_id',
#        'add_to_cart_order', 'reordered', '_merge', 'product_name', 'aisle_id',
#        'department_id', 'prices', ' price_range_loc', 'price_range_loc',
#        'busiest_day', 'busiest_days', 'busiest_period_of_day', 'max_order',
#        'loyalty_flag', 'mean_spend', 'spender_flag', 'median_order_frequency',
#        'order_frequency_flag', 'Unnamed: 0', 'First Name', 'Surnam', 'Gender',
#        'STATE', 'Age', 'date_joined', 'dependents', 'fam_status', 'income'],
#       dtype='object')

# %%
df_merged.columns
# Out:
# Index(['order_id', 'user_id', 'eval_set', 'order_number', 'orders_day_of_week',
#        'order_hour', 'days_since_prior_order', 'product_id',
#        'add_to_cart_order', 'reordered', '_merge', 'product_name', 'aisle_id',
#        'department_id', 'prices', ' price_range_loc', 'price_range_loc',
#        'busiest_day', 'busiest_days', 'busiest_period_of_day', 'max_order',
#        'loyalty_flag', 'mean_spend', 'spender_flag', 'median_order_frequency',
#        'order_frequency_flag', 'Unnamed: 0', 'First Name', 'Surnam', 'Gender',
#        'STATE', 'Age', 'date_joined', 'dependents', 'fam_status', 'income'],
#       dtype='object')

# %%
# Renaming 'Surnam' column 
df_merged.rename(columns = {'Surnam' : 'Surname'}, inplace = True)

# %%
df_merged.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  order_hour  \
# 0   2539329        1    prior             1                   2           8
# 1   2398795        1    prior             2                   3           7
# 2    473747        1    prior             3                   3          12
# 3   2254736        1    prior             4                   4           7
# 4    431534        1    prior             5                   4          15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  ...  \
# 0                     7.0         196                  1          0  ...
# 1                    15.0         196                  1          1  ...
# 2                    21.0         196                  1          1  ...
# 3                    29.0         196                  1          1  ...
# 4                    28.0         196                  1          1  ...
#
# ...

# %%
# Export cobined data
df_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_customers_merged.pkl'))
